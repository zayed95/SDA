# %%
import pandas as pd 
import matplotlib.pyplot as plt
df = pd.read_csv("../data/processed/processed-data.csv")

# %%
df.describe().T
# Out:
#                count unique  \
# created_at      1011   1008
# username        1011    381
# text            1011   1005
# processed_text  1011    931
# sentiment       1009      3
#
#                                                               top freq
# created_at                               2026-04-13T09:52:14.000Z    2
# username                                 trumpwatch.skyfleet.blue   79
# text            U.S. Democrats celebrated the defeat of ​Hunga...    2
# processed_text         translator google google translator object   68
# sentiment                                                 OPINION  754

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1011 entries, 0 to 1010
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   created_at      1011 non-null   str
#  1   username        1011 non-null   str
#  2   text            1011 non-null   str
#  3   processed_text  1011 non-null   str
#  4   sentiment       1009 non-null   str
# dtypes: str(5)
# memory usage: 597.2 KB

# %%
df.dropna(inplace=True)

# %%
df['sentiment'] = df['sentiment'].apply(lambda x: x.lower())

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# opinion    961
# fact        48
# Name: count, dtype: int64

# %%
plt.hist(x=df['sentiment'])
plt.show()
