# %%
import pandas as pd 
df = pd.read_csv("/media/omneya/OS/Users/pc/D/projects/SDA/data/processed-data.csv")

# %%
df['sentiment'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: sentiment, dtype: float64
